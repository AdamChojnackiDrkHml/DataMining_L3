# %%
from numpy import random
import numpy as np
import statsmodels.api as sm
from matplotlib import pyplot as plt

# %%
rng = np.random.default_rng (10)
x1 = rng.uniform(0, 1, size =100)
x2 = 0.5 * x1 + rng.normal(size =100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size =100)

# %%
plt.scatter(x1, x2)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
obs = np.stack((x1, x2), axis = -1)

x = sm.add_constant(obs)
model = sm.OLS(y, x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     20.17
# Date:                Mon, 06 Nov 2023   Prob (F-statistic):           4.60e-08
# Time:                        20:41:53   Log-Likelihood:                -135.30
# No. Observations:                 101   AIC:                             276.6
# Df Residuals:                      98   BIC:                             284.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0618      0.192     10.720      0.000       1.680       2.443
# ...

# %%
x = sm.add_constant(x1)
model = sm.OLS(y, x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     27.42
# Date:                Mon, 06 Nov 2023   Prob (F-statistic):           9.23e-07
# Time:                        20:41:58   Log-Likelihood:                -140.37
# No. Observations:                 101   AIC:                             284.7
# Df Residuals:                      99   BIC:                             290.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0739      0.201     10.310      0.000       1.675       2.473
# ...

# %%
x = sm.add_constant(x2)
model = sm.OLS(y, x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     36.10
# Date:                Mon, 06 Nov 2023   Prob (F-statistic):           3.13e-08
# Time:                        20:42:05   Log-Likelihood:                -137.01
# No. Observations:                 101   AIC:                             278.0
# Df Residuals:                      99   BIC:                             283.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2840      0.151     15.088      0.000       1.984       2.584
# ...

# %% [markdown]
# Nie ma sprzeczności, w c pokazaliśmy tylko, że $x_2$ *może* nic nie wnosić, ale w poprzednim podpunkcie temu zaprzeczyliśmy

# %%
plt.scatter(x1, y)
plt.scatter(0.1, 6)
plt.show()

# %%
plt.scatter(x2, y)
plt.scatter(0.8, 6)
plt.show()

# %%
plt.scatter(x1, x2)
plt.scatter(0.1, 0.8)
plt.show()

# %%
x1 = np.concatenate ([x1 , [0.1]])
x2 = np.concatenate ([x2 , [0.8]])
y = np.concatenate ([y, [6]])

# %%
obs = np.stack((x1, x2), axis = -1)

x = sm.add_constant(obs)
model = sm.OLS(y, x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     20.17
# Date:                Mon, 06 Nov 2023   Prob (F-statistic):           4.60e-08
# Time:                        20:42:10   Log-Likelihood:                -135.30
# No. Observations:                 101   AIC:                             276.6
# Df Residuals:                      98   BIC:                             284.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0618      0.192     10.720      0.000       1.680       2.443
# ...

# %%
x = sm.add_constant(x1)
model = sm.OLS(y, x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     27.42
# Date:                Mon, 06 Nov 2023   Prob (F-statistic):           9.23e-07
# Time:                        20:42:16   Log-Likelihood:                -140.37
# No. Observations:                 101   AIC:                             284.7
# Df Residuals:                      99   BIC:                             290.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0739      0.201     10.310      0.000       1.675       2.473
# ...

# %%
x = sm.add_constant(x2)
model = sm.OLS(y, x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     36.10
# Date:                Mon, 06 Nov 2023   Prob (F-statistic):           3.13e-08
# Time:                        20:42:23   Log-Likelihood:                -137.01
# No. Observations:                 101   AIC:                             278.0
# Df Residuals:                      99   BIC:                             283.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2840      0.151     15.088      0.000       1.984       2.584
# ...
